# %%
# Model weights
int(70*0.5)
# Out:
# 35

# %%
# Activation
35*0.2
# Out:
# 7.0

# %%
#KV cache per token
(8192*2*0.5*80)/10**9  #MB   2.6 MB
# Out:
# 0.00065536

# %%
#KV cache total
1*4096*0.0006  #10.65
# Out:
# 2.4576

# %%
# total vram 
(35+7+2.46)*1.15
# Out:
# 51.129

# %%
# total vram 
(140+28+10.65)*1.15
# Out:
# 205.4475
